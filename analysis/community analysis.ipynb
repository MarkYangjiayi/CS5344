# %%
import networkx as nx
import os
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# allowing the plot in line for seaborn
# %matplotlib inline
plt.style.use('seaborn')

# enabling outlines line in histogram
plt.rcParams["patch.force_edgecolor"] = True

from networkx.algorithms.community.quality import coverage, modularity

# %% [markdown]
# ### Load graph and read basic information

# %%
vax_g = nx.read_gml('D:/AAA_NUS/CS5344/data/graph/Final_Graph_sentiment_Vax.gml')
vax_dig = nx.read_gml('D:/AAA_NUS/CS5344/data/graph/Final_DiGraph_sentiment_Vax.gml')

# %%
print(nx.info(vax_g))
print('-------------------------------------------')
print(nx.info(vax_dig))
# Out:
# Graph named 'Final vax Graph' with 394344 nodes and 816593 edges
# -------------------------------------------
# DiGraph named 'Final vax Direct Graph' with 394344 nodes and 931993 edges

# %%
from analysis.analysis_utils import create_graph_df

vax_df = create_graph_df(vax_g)
# Out:
#   0%|          | 0/394344 [00:00<?, ?it/s]

# %% [markdown]
# ### Centrality

# %%
from analysis.analysis_utils import extract_community

comm_0 = extract_community(vax_dig, 0, 'sentimentComm')
comm_1 = extract_community(vax_dig, 1, 'sentimentComm')

# %%
from analysis_utils import compute_degree, compute_betweenness

compute_degree(comm_0, 1)
compute_degree(comm_1, 1)
# Out:
# MultiDiGraph with 202608 nodes and 1477784 edges
# MultiDiGraph with 202608 nodes and 1477784 edges
# degree: [('boxmenot', 0.15066606780614689), ('emmagpaley', 0.13276935150315636), ('lalaruefrench75', 0.12792252982374744), ('kidoctr', 0.12082504553149694), ('sheldon_walker_', 0.11611148676995366), ('veritasever', 0.10906335911394967), ('just4thecause', 0.10862902071498023), ('mcfunny', 0.09317545790619278), ('rosewind2007', 0.08025389053685213), ('coercedtaxslave', 0.07919765852117647)]
# MultiDiGraph with 191736 nodes and 820028 edges
# MultiDiGraph with 191736 nodes and 820028 edges
# degree: [('mcvaccination', 0.085013169217931), ('saverdemocrazy', 0.04517172138628837), ('anilsiri19', 0.039533731452264846), ('menakasanthush', 0.03811510678801471), ('solarcx69', 0.02464860354134613), ('publichealthnew', 0.02099251571178971), ('1grippe', 0.02033014316634939), ('vaccine_bio', 0.01177145539416382), ('vaccinologie', 0.011364643909562678), ('dbdcentre', 0.010874383915299763)]

# %%
compute_betweenness(comm_0)
compute_betweenness(comm_1)
# Out:
# MultiDiGraph with 202608 nodes and 1477784 edges
# MultiDiGraph with 202608 nodes and 1477784 edges
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6356/3869789992.py in <module>
# ----> 1 compute_betweenness(comm_0)
#       2 compute_betweenness(comm_1)
#
# D:\AAA_NUS\CS5344\analysis\analysis_utils.py in compute_betweenness(graph)
#      65
#      66     k = int(len(graph)*0.6)
# ---> 67     betweenness = betweenness_centrality(graph, k = k, normalized = True, weight = 'weight')
#      68     betweenness_sorted = sorted(betweenness.items(), key=lambda x: x[1], reverse=True)
#      69     print('between:',betweenness_sorted[0:10])
#
# D:\anaconda\envs\cs5344\lib\site-packages\networkx\utils\decorators.py in argmap_betweenness_centrality_10(G, k, normalized, weight, endpoints, seed)
#       3 from contextlib import contextmanager
#       4 from pathlib import Path
# ----> 5 import warnings
#       6
#       7 import networkx as nx
#
# D:\anaconda\envs\cs5344\lib\site-packages\networkx\algorithms\centrality\betweenness.py in betweenness_centrality(G, k, normalized, weight, endpoints, seed)
#     129                            directed=G.is_directed(), k=k, endpoints=endpoints)
#     130     return betweenness
# --> 131
#     132
#     133 @py_random_state(4)
#
# D:\anaconda\envs\cs5344\lib\site-packages\networkx\algorithms\centrality\betweenness.py in _single_source_dijkstra_path_basic(G, s, weight)
#     281             if w not in D and (w not in seen or vw_dist < seen[w]):
#     282                 seen[w] = vw_dist
# --> 283                 push(Q, (vw_dist, next(c), v, w))
#     284                 sigma[w] = 0.0
#     285                 P[w] = [v]
#
# KeyboardInterrupt:

# %% [markdown]
# ### Member in Community

# %%
from analysis.analysis_utils import community_pie_chart

community_pie_chart(vax_g, 'sentimentComm', 'Member in Two Communities')

# %%
from analysis.analysis_utils import plot_sentiment_distribution1
from analysis.analysis_utils import plot_sentiment_distribution2

plot_sentiment_distribution1(vax_g, 'Distribution of Sentiment Score', vax_df)
plot_sentiment_distribution2(vax_g, 'Distribution of Sentiment Score', vax_df)
# Out:
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Degree

# %%
from analysis.analysis_utils import plot_degree_distribution

plot_degree_distribution(vax_dig, 'Distribution of Degree', 0)
# Out:
#   0%|          | 0/394344 [00:00<?, ?it/s]

# %%
print(vax_df.columns[2:len(vax_df.columns)])
# Out:
# Index(['sentimentComm'], dtype='object')

# %%
vax_df.to_csv('vax_df.csv')
