# %%
import networkx as nx
import os
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# allowing the plot in line for seaborn
# %matplotlib inline
plt.style.use('seaborn')

# enabling outlines line in histogram
plt.rcParams["patch.force_edgecolor"] = True

from networkx.algorithms.community.quality import coverage, modularity

# %%
vax_dig = nx.read_gml('../data/graph/Final_DiGraph_sentiment_Vax.gml')

# %%
vax_dig.nodes.data()
# Out:
# NodeDataView({'lq_azalea': {'tweet': 'What he means is: there is no treatment for Dengue. It is viral, no antibiotic will work.   The key is prevention: by vaccination, by cleaning the surroundings.', 'sentiment': -4.538726682887265, 'sentimentComm': 1}, 'magnetronmagne1': {'sentiment': 0, 'sentimentComm': 1}, 'corybooker': {'sentiment': 0, 'sentimentComm': 0}, 'sa09152018': {'sentiment': -28.135644768856448, 'sentimentComm': 1}, 'msmariat': {'sentiment': 0, 'sentimentComm': 0}, 'charlottewilto4': {'sentiment': -20.68734793187348, 'sentimentComm': 1}, 'afmworgau': {'sentiment': 0, 'sentimentComm': 1}, 'acharenus': {'tweet': "Did she actually say that, a lot of people say she's an anti-vaxxer as well.  Turns out she just doesn't want government enforced vaccination.  I'm on anti-depressents too, just there appears to be A LOT of misinformation about her out there.", 'sentiment': 2.31295620437956, 'sentimentComm': 0}, 'reasonrhymes': {'sentiment': -8.734793187347929, 'sentimentComm': 0
# ...

# %%
result=[]
for node in

    # if(vax_dig.nodes[node]['tweet']!=None):
    #     tweet = vax_dig.nodes[node]['tweet']
    #     com = vax_dig.nodes[node]['sentimentComm']
    #     result.append((tweet,com))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cd/b7gg45d50mq8jrmlbr57lcm40000gn/T/ipykernel_6671/2399640354.py in <module>
#       1 result=[]
# ----> 2 node = vax_dig.nodes()[0]
#       3 print(node)
#       4
#       5     # if(vax_dig.nodes[node]['tweet']!=None):
#
# /opt/anaconda3/envs/cs5344/lib/python3.7/site-packages/networkx/classes/reportviews.py in __getitem__(self, n)
#     176
#     177     def __getitem__(self, n):
# --> 178         return self._nodes[n]
#     179
#     180     # Set methods
#
# KeyError: 0
