# %%
import networkx as nx
import os
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# allowing the plot in line for seaborn
# %matplotlib inline
plt.style.use('seaborn')

# enabling outlines line in histogram
plt.rcParams["patch.force_edgecolor"] = True

from networkx.algorithms.community.quality import coverage, modularity
from analysis.analysis_utils import create_graph_df
from analysis.analysis_utils import extract_community
from analysis_utils import compute_degree, compute_betweenness
from analysis.analysis_utils import community_pie_chart
from analysis.analysis_utils import plot_sentiment_distribution1
from analysis.analysis_utils import plot_sentiment_distribution2
from analysis_utils import plot_degree_distribution

# %% [markdown]
# # s1

# %% [markdown]
# ### Load graph and read basic information

# %%
vax_g_s1 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/s1/Final_Graph_sentiment_Vax.gml')
vax_dig_s1 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/s1/Final_DiGraph_sentiment_Vax.gml')

# %%
print(nx.info(vax_g_s1))
print('-------------------------------------------')
print(nx.info(vax_dig_s1))
# Out:
# Name: Final vax Graph
# Type: Graph
# Number of nodes: 3080
# Number of edges: 34749
# Average degree:  22.5643
# -------------------------------------------
# Name: Final vax Direct Graph
# Type: DiGraph
# Number of nodes: 3080
# Number of edges: 35734
# Average in degree:  11.6019
# Average out degree:  11.6019

# %%
vax_df_s1 = create_graph_df(vax_g_s1)
# Out:
#   0%|          | 0/3080 [00:00<?, ?it/s]

# %% [markdown]
# ### Centrality

# %%
comm_0_s1 = extract_community(vax_dig_s1, 0, 'sentimentComm')
comm_1_s1 = extract_community(vax_dig_s1, 1, 'sentimentComm')

# %%
compute_degree(comm_0_s1, 1)
compute_degree(comm_1_s1, 1)
# Out:
# Name:
# Type: MultiDiGraph
# Number of nodes: 1496
# Number of edges: 27730
# Average in degree:  18.5361
# Average out degree:  18.5361
# Name:
# Type: MultiDiGraph
# Number of nodes: 1496
# Number of edges: 27730
# Average in degree:  18.5361
# Average out degree:  18.5361
# degree: [('abscbnnews', 0.7678929765886288), ('inquirerdotnet', 0.7357859531772575), ('dzrhnews', 0.45551839464882943), ('cnnphilippines', 0.43010033444816054), ('pnagovph', 0.345819397993311), ('manilabulletin', 0.3411371237458194), ('philippinestar', 0.3391304347826087), ('dzmmteleradyo', 0.32508361204013375), ('ancalerts', 0.31304347826086953), ('newsrmn', 0.3010033444816053)]
# Name:
# Type: MultiDiGraph
# Number of nodes: 1584
# Number of edges: 26914
# Average in degree:  16.9912
# Average out degree:  16.9912
# Name:
# Type: MultiDiGraph
# Number of nodes: 1584
# Number of edges: 26914
# Average in degree:  16.9912
# Average out degree:  16.9912
# degree: [('dzbb', 0.509159823120657), ('philstarnews', 0.2324699936828806), ('news5ph', 0.19898926089703095), ('llanescajourno', 0.17814276689829436), ('kimmbadbadon', 0.1667719519898926), ('mjblancaflor', 0.16171825647504737), ('onenewsph', 0.15540113708149084), ('dpiresearch', 0.15476942514213518), ('ce_chinaeconomy', 0.14150347441566644), ('alexisbromero', 0.13202779532533163)]

# %%
compute_betweenness(comm_0_s1)
compute_betweenness(comm_1_s1)
# Out:
# between: [('cgtnamerica', 0.0), ('rushdy_nizar', 0.0), ('fordantitrust', 0.0), ('lim_singa', 0.0), ('guerreroespejo', 0.0), ('zvalatvija', 0.0), ('wengsalvacion', 0.0), ('jai93zam', 0.0), ('ethealthworld', 0.0), ('basuashis', 0.0)]
# between: [('', 0.0), ('nicky_zwan', 0.0), ('emmalyncooperm1', 0.0), ('nontandomagagu3', 0.0), ('discoverdaxing', 0.0), ('sandieshoes', 0.0), ('[', 0.0), ('drtedros', 0.0), ('lekh27', 0.0), ('myabime', 0.0)]

# %% [markdown]
# ### Member in Community

# %%
community_pie_chart(vax_g_s1, 'sentimentComm', 'Member in Two Communities (sinovac)')

# %%
plot_sentiment_distribution1(vax_g_s1, 'Distribution of Sentiment Score (sinovac)', vax_df_s1)
plot_sentiment_distribution2(vax_g_s1, 'Distribution of Sentiment Score (sinovac)', vax_df_s1)
# Out:
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Degree

# %%
plot_degree_distribution(vax_dig_s1, 'Distribution of Degree (sinovac)', 0)
# Out:
#   0%|          | 0/3080 [00:00<?, ?it/s]
#       degree_value community    towards placeholder
# 0              5.0         1  outdegree
# 2              7.0         1  outdegree
# 3              0.0         1   indegree
# 4              9.0         1  outdegree
# 5              0.0         1   indegree
# ...            ...       ...        ...         ...
# 6154          15.0         0  outdegree
# 6155           0.0         0   indegree
# 6156          12.0         0  outdegree
# 6157           0.0         0   indegree
# 6159           1.0         1   indegree
#
# [5242 rows x 4 columns]

# %%
vax_df_s1.to_csv('vax_df_mention_s1.csv')

# %% [markdown]
# # s2

# %%
vax_g_s2 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/s2/Final_Graph_sentiment_Vax.gml')
vax_dig_s2 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/s2/Final_DiGraph_sentiment_Vax.gml')

print(nx.info(vax_g_s2))
print('-------------------------------------------')
print(nx.info(vax_dig_s2))
# Out:
# Name: Final vax Graph
# Type: Graph
# Number of nodes: 477
# Number of edges: 4889
# Average degree:  20.4990
# -------------------------------------------
# Name: Final vax Direct Graph
# Type: DiGraph
# Number of nodes: 477
# Number of edges: 4988
# Average in degree:  10.4570
# Average out degree:  10.4570

# %%
vax_df_s2 = create_graph_df(vax_g_s2)
# Out:
#   0%|          | 0/477 [00:00<?, ?it/s]

# %%
comm_0_s2 = extract_community(vax_dig_s2, 0, 'sentimentComm')
comm_1_s2 = extract_community(vax_dig_s2, 1, 'sentimentComm')

compute_degree(comm_0_s2, 1)
compute_degree(comm_1_s2, 1)
# Out:
# Name:
# Type: MultiDiGraph
# Number of nodes: 232
# Number of edges: 1410
# Average in degree:   6.0776
# Average out degree:   6.0776
# Name:
# Type: MultiDiGraph
# Number of nodes: 232
# Number of edges: 1410
# Average in degree:   6.0776
# Average out degree:   6.0776
# degree: [('mehmetali_kutlu', 0.11255411255411256), ('pro13caraga', 0.11255411255411256), ('thevibesnews', 0.10822510822510822), ('kathmandupost', 0.1038961038961039), ('nepal_news_en', 0.1038961038961039), ('mgilijaccc', 0.09956709956709957), ('rgsealey', 0.09090909090909091), ('501awani', 0.07792207792207792), ('boosulyn', 0.06926406926406926), ('padrealex', 0.06926406926406926)]
# Name:
# Type: MultiDiGraph
# Number of nodes: 245
# Number of edges: 3606
# Average in degree:  14.7184
# Average out degree:  14.7184
# Name:
# Type: MultiDiGraph
# Number of nodes: 245
# Number of edges: 3606
# Average in degree:  14.7184
# Average out degree:  14.7184
# degree: [('kerwinso', 0.9262295081967213), ('sinovac', 0.5901639344262295), ('stephiekeachie', 0.33606557377049184), ('voastevenson', 0.319672131147541), ('deng_yiming05', 0.29508196721311475), ('marytherobot', 0.2377049180327869), ('maawlaw', 0.22540983606557377), ('shen_shiwei', 0.20081967213114754), ('bridgebeijing', 0.19672131147540983), ('mdsynic', 0.18032786885245902)]

# %%
compute_betweenness(comm_0_s2)
compute_betweenness(comm_1_s2)
# Out:
# between: [('x', 0.0), ('tedkempcnbc', 0.0), ('amubaidahs', 0.0), ('eileenlow8', 0.0), ('fousurlacolline', 0.0), ('nica__68', 0.0), ('razasidique', 0.0), ('j', 0.0), ('sayyedalifkhan', 0.0), ('nycguidovoice', 0.0)]
# between: [('', 0.0), ('[', 0.0), ('todobiranews', 0.0), ('shakirameer', 0.0), ('philipp77125423', 0.0), ('zaldytor', 0.0), ('voastevenson', 0.0), ('rupertbu', 0.0), ('angeldommeaijin', 0.0), ('williamrubio', 0.0)]

# %%
community_pie_chart(vax_g_s2, 'sentimentComm', 'Member in Two Communities (sinovac)')

# %%
plot_sentiment_distribution1(vax_g_s2, 'Distribution of Sentiment Score (sinovac)', vax_df_s2)
plot_sentiment_distribution2(vax_g_s2, 'Distribution of Sentiment Score (sinovac)', vax_df_s2)
# Out:
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plot_degree_distribution(vax_dig_s2, 'Distribution of Degree (sinovac)', 0)
# Out:
#   0%|          | 0/477 [00:00<?, ?it/s]
#      degree_value community    towards placeholder
# 0             0.0         1  outdegree
# 3             0.0         0   indegree
# 4             0.0         1  outdegree
# 6            12.0         1  outdegree
# 7             1.0         1   indegree
# ..            ...       ...        ...         ...
# 949           0.0         1   indegree
# 950          18.0         1  outdegree
# 951           1.0         1   indegree
# 952          18.0         1  outdegree
# 953           0.0         1   indegree
#
# [825 rows x 4 columns]

# %%
vax_df_s2.to_csv('vax_df_mention_s2.csv')

# %% [markdown]
# # v1

# %%
vax_g_v1 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/v1/Final_Graph_sentiment_Vax.gml')
vax_dig_v1 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/v1/Final_DiGraph_sentiment_Vax.gml')

print(nx.info(vax_g_v1))
print('-------------------------------------------')
print(nx.info(vax_dig_v1))
# Out:
# Name: Final vax Graph
# Type: Graph
# Number of nodes: 23532
# Number of edges: 39482
# Average degree:   3.3556
# -------------------------------------------
# Name: Final vax Direct Graph
# Type: DiGraph
# Number of nodes: 23532
# Number of edges: 43874
# Average in degree:   1.8644
# Average out degree:   1.8644

# %%
vax_df_v1 = create_graph_df(vax_g_v1)
# Out:
#   0%|          | 0/23532 [00:00<?, ?it/s]

# %%
comm_0_v1 = extract_community(vax_dig_v1, 0, 'sentimentComm')
comm_1_v1 = extract_community(vax_dig_v1, 1, 'sentimentComm')

compute_degree(comm_0_v1, 1)
compute_degree(comm_1_v1, 1)
# Out:
# Name:
# Type: MultiDiGraph
# Number of nodes: 11451
# Number of edges: 32703
# Average in degree:   2.8559
# Average out degree:   2.8559
# Name:
# Type: MultiDiGraph
# Number of nodes: 11451
# Number of edges: 32703
# Average in degree:   2.8559
# Average out degree:   2.8559
# degree: [('classnet007', 0.04733624454148471), ('latestly', 0.017117903930131004), ('ontariovax', 0.015458515283842794), ('moneycontrolcom', 0.01336244541484716), ('fpjindia', 0.012838427947598253), ('outlookindia', 0.012663755458515284), ('puducherryfob', 0.011441048034934497), ('abscbnnews', 0.011353711790393012), ('httweets', 0.010829694323144104), ('abpnews', 0.010305676855895196)]
# Name:
# Type: MultiDiGraph
# Number of nodes: 12081
# Number of edges: 34640
# Average in degree:   2.8673
# Average out degree:   2.8673
# Name:
# Type: MultiDiGraph
# Number of nodes: 12081
# Number of edges: 34640
# Average in degree:   2.8673
# Average out degree:   2.8673
# degree: [('vaccinate_fla', 0.11183774834437087), ('vaxhunterscan', 0.06597682119205298), ('covid19rdcbot', 0.0326158940397351), ('mediaactive', 0.011754966887417218), ('jenniferclmn', 0.010347682119205299), ('vaxyourfam', 0.01009933774834437), ('peninsulaqatar', 0.009850993377483444), ('oneindiakannada', 0.008774834437086093), ('ichinadian', 0.008029801324503311), ('maawlaw', 0.0074503311258278145)]

# %%
compute_betweenness(comm_0_v1)
compute_betweenness(comm_1_v1)
# Out:
# between: [('mohfw_india', 0.0002096012196045655), ('gavi', 0.00012939550358974776), ('who', 0.00012590313886790198), ('drtedros', 0.00011106058880005735), ('drharshvardhan', 9.920392580325683e-05), ('nychealthsystem', 9.500588301564971e-05), ('whoafro', 8.91972836815603e-05), ('coneyislandhosp', 7.831119291935046e-05), ('mygovindia', 6.533773610676552e-05), ('cepivaccines', 6.460133031742001e-05)]
# between: [('vaxhunterscan', 0.00011664202756632514), ('cpho_canada', 3.372692061400206e-05), ('johntory', 2.6912997448463623e-05), ('clarkcountynv', 2.5285195183435582e-05), ('onthealth', 1.6483639778494486e-05), ('hcphtx', 1.3742078068973573e-05), ('cityoftoronto', 1.3462210311126647e-05), ('epdevilla', 1.3370824920809283e-05), ('moriartylab', 1.1514559179987831e-05), ('thewechu', 1.0555012581655512e-05)]

# %%
community_pie_chart(vax_g_v1, 'sentimentComm', 'Member in Two Communities (vaccine)')

# %%
plot_sentiment_distribution1(vax_g_v1, 'Distribution of Sentiment Score (vaccine)', vax_df_v1)
plot_sentiment_distribution2(vax_g_v1, 'Distribution of Sentiment Score (vaccine)', vax_df_v1)
# Out:
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plot_degree_distribution(vax_dig_v1, 'Distribution of Degree (vaccine)', 0)
# Out:
#   0%|          | 0/23532 [00:00<?, ?it/s]
#        degree_value community    towards placeholder
# 1               1.0         0   indegree
# 2               2.0         0  outdegree
# 3               1.0         0   indegree
# 4               1.0         1  outdegree
# 5               0.0         1   indegree
# ...             ...       ...        ...         ...
# 47059           0.0         1   indegree
# 47060           1.0         1  outdegree
# 47061           0.0         1   indegree
# 47062           0.0         1  outdegree
# 47063           2.0         1   indegree
#
# [40693 rows x 4 columns]

# %%
vax_df_v1.to_csv('vax_df_mention_v1.csv')

# %% [markdown]
# # v2

# %%
vax_g_v2 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/v2/Final_Graph_sentiment_Vax.gml')
vax_dig_v2 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/v2/Final_DiGraph_sentiment_Vax.gml')

print(nx.info(vax_g_v2))
print('-------------------------------------------')
print(nx.info(vax_dig_v2))
# Out:
# Name: Final vax Graph
# Type: Graph
# Number of nodes: 9940
# Number of edges: 13901
# Average degree:   2.7970
# -------------------------------------------
# Name: Final vax Direct Graph
# Type: DiGraph
# Number of nodes: 9940
# Number of edges: 15712
# Average in degree:   1.5807
# Average out degree:   1.5807

# %%
vax_df_v2 = create_graph_df(vax_g_v2)
# Out:
#   0%|          | 0/9940 [00:00<?, ?it/s]

# %%
comm_0_v2 = extract_community(vax_dig_v2, 0, 'sentimentComm')
comm_1_v2 = extract_community(vax_dig_v2, 1, 'sentimentComm')

compute_degree(comm_0_v2, 1)
compute_degree(comm_1_v2, 1)
# Out:
# Name:
# Type: MultiDiGraph
# Number of nodes: 5114
# Number of edges: 15450
# Average in degree:   3.0211
# Average out degree:   3.0211
# Name:
# Type: MultiDiGraph
# Number of nodes: 5114
# Number of edges: 15450
# Average in degree:   3.0211
# Average out degree:   3.0211
# degree: [('speakertimjones', 0.04928613338548797), ('nodude504_fox', 0.04283199687072169), ('vaxyourfam', 0.04204967729317426), ('nychealthsystem', 0.03559554077840798), ('mtmdphd', 0.030119303735575982), ('springcanadian1', 0.029336984158028555), ('maawlaw', 0.026990025425386272), ('chriscostatv', 0.026012125953451985), ('kakmidah', 0.02386074711519656), ('agenciaajn', 0.02386074711519656)]
# Name:
# Type: MultiDiGraph
# Number of nodes: 4826
# Number of edges: 18610
# Average in degree:   3.8562
# Average out degree:   3.8562
# Name:
# Type: MultiDiGraph
# Number of nodes: 4826
# Number of edges: 18610
# Average in degree:   3.8562
# Average out degree:   3.8562
# degree: [('vaxyork', 0.2833160621761658), ('covid19rdcbot', 0.2511917098445596), ('vaxhunterson', 0.21927461139896373), ('cityoftoronto', 0.06466321243523317), ('ymediagroup', 0.04020725388601036), ('puducherryfob', 0.038134715025906735), ('translateirl', 0.03564766839378238), ('du_pangolin', 0.03150259067357513), ('rcdhealthunit', 0.03129533678756477), ('durhamhealth', 0.031088082901554404)]

# %%
compute_betweenness(comm_0_v2)
compute_betweenness(comm_1_v2)
# Out:
# between: [('us_fda', 0.00010579986573535003), ('pfizer', 9.06855992017286e-05), ('cdcgov', 7.902571847923724e-05), ('timeisliferod', 5.18476738052077e-05), ('nachc', 3.864660556698139e-05), ('hhsgov', 3.6414540889020416e-05), ('hrsagov', 3.5521715017836024e-05), ('kff', 3.50859309616627e-05), ('moderna_tx', 3.348097016941457e-05), ('novavax', 3.1727205065302375e-05)]
# between: [('who', 0.00037373687500860426), ('doctorsoumya', 0.0002603863363601946), ('gavi', 0.0001717446872444522), ('mohfw_india', 0.00014059000044239353), ('ddnewslive', 0.00013636442223245913), ('drtedros', 6.603361202643242e-05), ('gaviseth', 4.748403988451702e-05), ('ifpma', 3.788696395008975e-05), ('covidnewsbymib', 3.7027524314170886e-05), ('pib_india', 3.548769496648293e-05)]

# %%
community_pie_chart(vax_g_v2, 'sentimentComm', 'Member in Two Communities (vaccine)')

# %%
plot_sentiment_distribution1(vax_g_v2, 'Distribution of Sentiment Score (vaccine)', vax_df_v2)
plot_sentiment_distribution2(vax_g_v2, 'Distribution of Sentiment Score (vaccine)', vax_df_v2)
# Out:
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plot_degree_distribution(vax_dig_v2, 'Distribution of Degree (vaccine)', 0)
# Out:
#   0%|          | 0/9940 [00:00<?, ?it/s]
#        degree_value community    towards placeholder
# 0               0.0         0  outdegree
# 1               1.0         0   indegree
# 2               3.0         0  outdegree
# 3               1.0         0   indegree
# 5               2.0         1   indegree
# ...             ...       ...        ...         ...
# 19874           0.0         0  outdegree
# 19876           0.0         1  outdegree
# 19877           2.0         1   indegree
# 19878           0.0         1  outdegree
# 19879           1.0         1   indegree
#
# [17255 rows x 4 columns]

# %%
vax_df_v2.to_csv('vax_df_mention_v2.csv')

# %% [markdown]
# # p1

# %%
vax_g_p1 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/p1/Final_Graph_sentiment_Vax.gml')
vax_dig_p1 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/p1/Final_DiGraph_sentiment_Vax.gml')

print(nx.info(vax_g_p1))
print('-------------------------------------------')
print(nx.info(vax_dig_p1))
# Out:
# Name: Final vax Graph
# Type: Graph
# Number of nodes: 40843
# Number of edges: 48365
# Average degree:   2.3683
# -------------------------------------------
# Name: Final vax Direct Graph
# Type: DiGraph
# Number of nodes: 40843
# Number of edges: 63043
# Average in degree:   1.5435
# Average out degree:   1.5435

# %%
vax_df_p1 = create_graph_df(vax_g_p1)
# Out:
#   0%|          | 0/40843 [00:00<?, ?it/s]

# %%
comm_0_p1 = extract_community(vax_dig_p1, 0, 'sentimentComm')
comm_1_p1 = extract_community(vax_dig_p1, 1, 'sentimentComm')

compute_degree(comm_0_p1, 1)
compute_degree(comm_1_p1, 1)
# Out:
# Name:
# Type: MultiDiGraph
# Number of nodes: 20595
# Number of edges: 58253
# Average in degree:   2.8285
# Average out degree:   2.8285
# Name:
# Type: MultiDiGraph
# Number of nodes: 20595
# Number of edges: 58253
# Average in degree:   2.8285
# Average out degree:   2.8285
# degree: [('sandiegocounty', 0.010439933961347965), ('northeasthealth', 0.008643294163348548), ('celimarrivera', 0.007575021851024571), ('exmooron', 0.007332232689132757), ('jerusalem_post', 0.007186559191997669), ('immuneresponseb', 0.007138001359619306), ('sailorrooscout', 0.007040885694862582), ('thegazmanrants', 0.006895212197727494), ('threadreaderapp', 0.006555307371078955), ('maawlaw', 0.006021171214916966)]
# Name:
# Type: MultiDiGraph
# Number of nodes: 20248
# Number of edges: 79219
# Average in degree:   3.9124
# Average out degree:   3.9124
# Name:
# Type: MultiDiGraph
# Number of nodes: 20248
# Number of edges: 79219
# Average in degree:   3.9124
# Average out degree:   3.9124
# degree: [('reuters_health', 0.015162740159035905), ('reuters', 0.013088358769200375), ('abscbnnews', 0.011409097644095421), ('pkb_canada', 0.010569467081542945), ('marilynrules1', 0.008544475724798736), ('cnnphilippines', 0.00795179532770287), ('inquirerdotnet', 0.007457894996789648), ('cityam', 0.0070627747320590704), ('kat_veritas', 0.006815824566602459), ('ptvph', 0.006667654467328493)]

# %%
compute_betweenness(comm_0_p1)
compute_betweenness(comm_1_p1)
# Out:
# between: [('pfizer', 0.00029636503256551234), ('albertbourla', 0.00017898163348675975), ('eu_commission', 3.523801000506552e-05), ('vonderleyen', 2.8639602733721628e-05), ('biontech_group', 2.6481398250986062e-05), ('us_fda', 1.7456894043662637e-05), ('g7', 1.6403664056336753e-05), ('matthancock', 6.845994917618261e-06), ('wionews', 6.187726175539582e-06), ('indiatoday', 3.0358961388404746e-06)]
# between: [('nbcnews', 2.525857703817934e-05), ('nbcnewsnow', 1.962703660065867e-05), ('msnbc', 8.526599492765948e-06), ('kavitapmd', 7.298639050793933e-06), ('ameshaa', 4.5052323500165336e-06), ('aliraja_md', 4.4117121839060825e-06), ('peterhotez', 4.330390300331776e-06), ('katyonmsnbc', 3.895318223209241e-06), ('ajenglish', 3.2691397196870877e-06), ('torontostar', 3.096330717091688e-06)]

# %%
community_pie_chart(vax_g_p1, 'sentimentComm', 'Member in Two Communities (Pfizer)')

# %%
plot_sentiment_distribution1(vax_g_p1, 'Distribution of Sentiment Score (Pfizer)', vax_df_p1)
plot_sentiment_distribution2(vax_g_p1, 'Distribution of Sentiment Score (Pfizer)', vax_df_p1)
# Out:
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plot_degree_distribution(vax_dig_p1, 'Distribution of Degree (Pfizer)', 0)
# Out:
#   0%|          | 0/40843 [00:00<?, ?it/s]
#        degree_value community    towards placeholder
# 0               1.0         0  outdegree
# 1               0.0         0   indegree
# 2               0.0         0  outdegree
# 3               1.0         0   indegree
# 4               0.0         0  outdegree
# ...             ...       ...        ...         ...
# 81680           1.0         0  outdegree
# 81681           0.0         0   indegree
# 81683           4.0         0   indegree
# 81684           4.0         0  outdegree
# 81685           3.0         0   indegree
#
# [69750 rows x 4 columns]

# %%
vax_df_p1.to_csv('vax_df_mention_p1.csv')

# %% [markdown]
# # p2

# %%
vax_g_p2 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/p2/Final_Graph_sentiment_Vax.gml')
vax_dig_p2 = nx.read_gml('D:/AAA_NUS/CS5344/data/graph_mention/p2/Final_DiGraph_sentiment_Vax.gml')

print(nx.info(vax_g_p2))
print('-------------------------------------------')
print(nx.info(vax_dig_p2))
# Out:
# Name: Final vax Graph
# Type: Graph
# Number of nodes: 14247
# Number of edges: 16257
# Average degree:   2.2822
# -------------------------------------------
# Name: Final vax Direct Graph
# Type: DiGraph
# Number of nodes: 14247
# Number of edges: 21214
# Average in degree:   1.4890
# Average out degree:   1.4890

# %%
vax_df_p2 = create_graph_df(vax_g_p2)
# Out:
#   0%|          | 0/14247 [00:00<?, ?it/s]

# %%
comm_0_p2 = extract_community(vax_dig_p2, 0, 'sentimentComm')
comm_1_p2 = extract_community(vax_dig_p2, 1, 'sentimentComm')

compute_degree(comm_0_p2, 1)
compute_degree(comm_1_p2, 1)
# Out:
# Name:
# Type: MultiDiGraph
# Number of nodes: 6916
# Number of edges: 18914
# Average in degree:   2.7348
# Average out degree:   2.7348
# Name:
# Type: MultiDiGraph
# Number of nodes: 6916
# Number of edges: 18914
# Average in degree:   2.7348
# Average out degree:   2.7348
# degree: [('vaxreports1', 0.016775126536514823), ('reuters', 0.014750542299349242), ('kathmlee1', 0.01200289226319595), ('abscbnnews', 0.01200289226319595), ('robertw41590898', 0.01200289226319595), ('inquirerdotnet', 0.011713665943600867), ('mcfunny', 0.010845986984815618), ('business', 0.010556760665220535), ('f250roush', 0.009833694866232827), ('girlnasty22', 0.00911062906724512)]
# Name:
# Type: MultiDiGraph
# Number of nodes: 7331
# Number of edges: 21781
# Average in degree:   2.9711
# Average out degree:   2.9711
# Name:
# Type: MultiDiGraph
# Number of nodes: 7331
# Number of edges: 21781
# Average in degree:   2.9711
# Average out degree:   2.9711
# degree: [('plhartungrn', 0.03765347885402456), ('exmooron', 0.0252387448840382), ('reuters_health', 0.016916780354706687), ('diego48979433', 0.0165075034106412), ('nomisinfotoday', 0.014051841746248296), ('thehill', 0.01227830832196453), ('roya__ro', 0.011050477489768078), ('sputnikvaccine', 0.010641200545702592), ('classicexter', 0.010641200545702592), ('turrialba27', 0.010231923601637109)]

# %%
compute_betweenness(comm_0_p2)
compute_betweenness(comm_1_p2)
# Out:
# between: [('erictopol', 8.785986485490576e-06), ('nytimes', 7.251925353103333e-06), ('peterhotez', 5.752729246452163e-06), ('todayshow', 5.299483911883205e-06), ('business', 4.915968628786394e-06), ('rebelnewsonline', 4.009477959648477e-06), ('usatoday', 2.5102818529973073e-06), ('apoorva_nyc', 1.9175764154840545e-06), ('wionews', 1.8129813382758332e-06), ('aaronsirisg', 1.6386562095954645e-06)]
# between: [('pfizer', 9.47348584224079e-05), ('cdcgov', 1.67863611790565e-05), ('albertbourla', 1.4055862502980766e-05), ('biontech_group', 9.184404637709284e-06), ('peoplesvaccine', 4.395689156561314e-06), ('b1llyth2k3d', 1.6755332785010184e-06), ('codex_dna', 1.613476490408387e-06), ('globaljusticeuk', 1.5669338993389155e-06), ('vonderleyen', 1.3962777320841821e-06), ('megtirrell', 1.365249338037867e-06)]

# %%
community_pie_chart(vax_g_p2, 'sentimentComm', 'Member in Two Communities (Pfizer)')

# %%
plot_sentiment_distribution1(vax_g_p2, 'Distribution of Sentiment Score (Pfizer)', vax_df_p2)
plot_sentiment_distribution2(vax_g_p2, 'Distribution of Sentiment Score (Pfizer)', vax_df_p2)
# Out:
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\envs\cs5344\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plot_degree_distribution(vax_dig_p2, 'Distribution of Degree (Pfizer)', 0)
# Out:
#   0%|          | 0/14247 [00:00<?, ?it/s]
#        degree_value community    towards placeholder
# 0               1.0         0  outdegree
# 1               0.0         0   indegree
# 2               1.0         1  outdegree
# 3               0.0         1   indegree
# 4               2.0         0  outdegree
# ...             ...       ...        ...         ...
# 28489           0.0         1   indegree
# 28490           2.0         0  outdegree
# 28491           1.0         0   indegree
# 28492           0.0         0  outdegree
# 28493           1.0         0   indegree
#
# [24818 rows x 4 columns]

# %%
vax_df_p2.to_csv('vax_df_mention_p2.csv')
